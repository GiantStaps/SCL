# %% [markdown]
# # Get Started

# %%
import pandas as pd
from transformers import BertModel, BertTokenizer
import torch
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
# Load a pre-trained BERT model and tokenizer
model_name = "bert-base-uncased"  # You can use other models like 'bert-large-uncased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

# Ensure model is in evaluation mode
model.eval()
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSdpaSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
df = pd.read_csv('data.csv', encoding = "cp1252")

# %%
df
# Out:
#                                                Entity                Contact  \
# 0        Advanced Manufacturing Pilot Facility (AMPF)          Aaron Stebner
# 1       Advanced Technology Development Center (ATDC)           Alex Rhodeen
# 2   Artificial Intelligence Institute for Advances...  Pascal Van Hentenryck
# 3                   Atlanta Regional Commission (ARC)             Anna Roach
# 4   Brook Byers Institute for Sustainable Systems ...           Beril Toktay
# ..                                                ...                    ...
# 75          Metro Atlanta Chamber of Commerce (MACOC)          Robert Herrig
# 76               Partnership for Inclusive Innovation         Rachel Cronin
# 77  Sentient Immersive Response Networks Lab (SIRe...                    NaN
# 78                    Smart Sea Level Sensors Project             Russ Clark
# 79             The Logistics Institute – Asia Pacific        Robert De Souza
#
#                         Contact Email Environment  \
# 0            aaron.stebner@gatech.edu    Internal
# 1                                 NaN    External
# 2                                 NaN    External
# 3                                 NaN    External
# 4    beril.toktay@scheller.gatech.edu    Internal
# ..                                ...         ...
# 75                  rherrig@macoc.com    External
# 76  Rachel.Cronin@innovate.gatech.edu    External
# 77                                NaN    External
# 78              russ.clark@gatech.edu    External
# 79                rdesouza@nus.edu.sg    External
#
#                                               Purpose  \
# 0   Provides a platform for developing and demonst...
# 1   Supports startups in scaling their operations ...
# 2   Conducts research and development in AI to opt...
# 3   Coordinates regional planning and development ...
# 4   Promotes sustainability through research and c...
# ..                                                ...
# 75  Represents businesses, colleges, universities,...
# 76  Promotes innovation and prosperity for all Geo...
# 77  Drives collaborative research and training in ...
# 78  Enhance flood monitoring and response in Chath...
# 79  Aims to be the premier institution for logisti...
#
#                                           Description  \
# 0   The Advanced Manufacturing Pilot Facility (AMP...
# 1   The Advanced Technology Development Center (AT...
# 2   This NSF Artificial Intelligence (AI) Research...
# 3   The Atlanta Regional Commission (ARC) is the o...
# 4   The Brook Byers Institute for Sustainable Syst...
# ..                                                ...
# 75  The Metro Atlanta Chamber (MAC) is a 165-year-...
# 76  The Partnership for Inclusive Innovation (PIN)...
# 77  On November 15, 2019, IMT Mines Albi and the G...
# 78  The Smart Sea Level Sensors Project aims to in...
# 79  The Logistics Institute - Asia Pacific, a coll...
#
#                                               Website Associated College  \
# 0                   https://ampf.research.gatech.edu/                NaN
# 1                                   https://atdc.org/                NaN
# 2                             https://www.ai4opt.org/                NaN
# 3                        https://atlantaregional.org/                NaN
# 4                  https://sustainability.gatech.edu/                NaN
# ..                                                ...                ...
# 75               https://www.metroatlantachamber.com/                NaN
# 76                             https://pingeorgia.org                NaN
# 77  https://www.imt-mines-albi.fr/en/actus/launchi...                NaN
# 78             https://www.sealevelsensors.org/about/                NaN
# 79                       http://www.tliap.nus.edu.sg/                NaN
#
#    Associated School                                 Parent Children  \
# 0                NaN   Georgia Tech Manufacturing Institute      NaN
# 1                NaN                                    NaN      NaN
# 2                NaN                                    NaN      NaN
# 3                NaN                                    NaN      NaN
# 4                NaN  Enterprise Innovation Institute (EI2)      NaN
# ..               ...                                    ...      ...
# 75               NaN                                    NaN      NaN
# 76               NaN                                    NaN      NaN
# 77               NaN                                    NaN      NaN
# 78               NaN                                    NaN      NaN
# 79               NaN                                    NaN      NaN
#
#                  Type                                            Focuses  \
# 0   Research/Industry                          Technology and Automation
# 1            External  Technology and Automation, Supply Chain Planni...
# 2            External  Technology and Automation, Supply Chain Planni...
# 3            External      Supply Chain Planning, Supply Chain Analytics
# 4   Research/Industry                 Sustainability and Green Logistics
# ..                ...                                                ...
# 75                NaN                                                NaN
# 76                NaN                                                NaN
# 77                NaN                                                NaN
# 78                NaN                                                NaN
# 79                NaN                                                NaN
#
#                                       Engagment Model Information Verified
# 0                                            Research                 False
# 1                           Industry Forum/Consortium                 False
# 2   Research, Education Innitiaves, Industry Forum...                 False
# 3                           Industry Forum/Consortium                 False
# 4                                            Research                 False
# ..                                                ...                   ...
# 75                                                NaN                   NaN
# 76                                                NaN                   NaN
# 77                                                NaN                   NaN
# 78                                                NaN                   NaN
# 79                                                NaN                   NaN
#
# [80 rows x 15 columns]

# %% [markdown]
# # Embed

# %%
def embed_text(text):
    # Tokenize the input text
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=512)
    
    # Pass through BERT model
    with torch.no_grad():
        outputs = model(**inputs)
    
    # Extract the embeddings (we'll use the [CLS] token's embedding as a summary)
    embeddings = outputs.last_hidden_state[:, 0, :]
    return embeddings.squeeze().numpy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Entity                 80 non-null     object
#  1   Contact                69 non-null     object
#  2   Contact Email          57 non-null     object
#  3   Environment            80 non-null     object
#  4   Purpose                79 non-null     object
#  5   Description            79 non-null     object
#  6   Website                80 non-null     object
#  7   Associated College     28 non-null     object
#  8   Associated School      17 non-null     object
#  9   Parent                 12 non-null     object
#  10  Children               4 non-null      object
#  11  Type                   64 non-null     object
#  12  Focuses                64 non-null     object
#  13  Engagment Model        13 non-null     object
#  14  Information Verified   64 non-null     object
#  15  Purpose_Embedding      80 non-null     object
#  16  Description_Embedding  80 non-null     object
# dtypes: object(17)
# memory usage: 10.8+ KB

# %%
df['Purpose_Embedding'] = df['Purpose'].astype(str).apply(embed_text)
df['Description_Embedding'] = df['Description'].astype(str).apply(embed_text)
# Out:
#                                                Entity  \
# 0        Advanced Manufacturing Pilot Facility (AMPF)
# 1       Advanced Technology Development Center (ATDC)
# 2   Artificial Intelligence Institute for Advances...
# 3                   Atlanta Regional Commission (ARC)
# 4   Brook Byers Institute for Sustainable Systems ...
# ..                                                ...
# 75          Metro Atlanta Chamber of Commerce (MACOC)
# 76               Partnership for Inclusive Innovation
# 77  Sentient Immersive Response Networks Lab (SIRe...
# 78                    Smart Sea Level Sensors Project
# 79             The Logistics Institute – Asia Pacific
#
#                                               Purpose  \
# 0   Provides a platform for developing and demonst...
# 1   Supports startups in scaling their operations ...
# 2   Conducts research and development in AI to opt...
# 3   Coordinates regional planning and development ...
# 4   Promotes sustainability through research and c...
# ..                                                ...
# 75  Represents businesses, colleges, universities,...
# 76  Promotes innovation and prosperity for all Geo...
# 77  Drives collaborative research and training in ...
# 78  Enhance flood monitoring and response in Chath...
# 79  Aims to be the premier institution for logisti...
#
#                                     Purpose_Embedding  \
# 0   [-0.7475531, -0.28025112, -0.5108066, -0.09811...
# 1   [-0.7059361, -0.014833092, -0.519372, -0.11807...
# 2   [-0.8444699, 0.042686164, -0.92527217, -0.0121...
# 3   [-0.9401546, -0.2008859, -0.8348193, -0.138634...
# 4   [-0.4857487, 0.15720437, -0.36733863, -0.27873...
# ..                                                ...
# 75  [-0.8119428, -0.16800997, -0.65266424, -0.2421...
# 76  [-0.806397, -0.08502055, -1.0574926, -0.420601...
# 77  [-0.82316875, 0.09686072, -0.31321028, 0.03096...
# 78  [-1.0763615, -0.4297121, -0.7915945, -0.108039...
# 79  [-0.6068448, -0.09858106, -0.37059268, -0.2740...
#
#                                           Description  \
# 0   The Advanced Manufacturing Pilot Facility (AMP...
# 1   The Advanced Technology Development Center (AT...
# 2   This NSF Artificial Intelligence (AI) Research...
# 3   The Atlanta Regional Commission (ARC) is the o...
# 4   The Brook Byers Institute for Sustainable Syst...
# ..                                                ...
# 75  The Metro Atlanta Chamber (MAC) is a 165-year-...
# 76  The Partnership for Inclusive Innovation (PIN)...
# 77  On November 15, 2019, IMT Mines Albi and the G...
# 78  The Smart Sea Level Sensors Project aims to in...
# 79  The Logistics Institute - Asia Pacific, a coll...
#
#                                 Description_Embedding
# 0   [-0.57778853, -0.2628846, -0.6567326, -0.44782...
# 1   [-0.8001564, -0.41133833, -0.7856436, 0.248099...
# 2   [-0.6534205, -0.22116624, -0.3180426, 0.109655...
# 3   [-0.5959657, 0.004410204, -0.7242155, -0.17405...
# 4   [-0.6693135, -0.14842133, -0.5588188, -0.12038...
# ..                                                ...
# 75  [-0.4659681, -0.43856305, -0.20382541, -0.3299...
# 76  [-0.5760279, -0.3649536, -0.9441599, -0.242495...
# 77  [-0.65241796, -0.13074902, -0.33428797, -0.093...
# 78  [-0.93810964, -0.528288, -0.5730109, -0.102771...
# 79  [-0.60964525, 0.10186995, -0.45152536, -0.2336...
#
# [80 rows x 5 columns]

# %%
# Display the DataFrame with embeddings
df[['Entity', 'Purpose', 'Purpose_Embedding', 'Description', 'Description_Embedding']]
# Out:
#                                                Entity  \
# 0        Advanced Manufacturing Pilot Facility (AMPF)
# 1       Advanced Technology Development Center (ATDC)
# 2   Artificial Intelligence Institute for Advances...
# 3                   Atlanta Regional Commission (ARC)
# 4   Brook Byers Institute for Sustainable Systems ...
# ..                                                ...
# 75          Metro Atlanta Chamber of Commerce (MACOC)
# 76               Partnership for Inclusive Innovation
# 77  Sentient Immersive Response Networks Lab (SIRe...
# 78                    Smart Sea Level Sensors Project
# 79             The Logistics Institute – Asia Pacific
#
#                                               Purpose  \
# 0   Provides a platform for developing and demonst...
# 1   Supports startups in scaling their operations ...
# 2   Conducts research and development in AI to opt...
# 3   Coordinates regional planning and development ...
# 4   Promotes sustainability through research and c...
# ..                                                ...
# 75  Represents businesses, colleges, universities,...
# 76  Promotes innovation and prosperity for all Geo...
# 77  Drives collaborative research and training in ...
# 78  Enhance flood monitoring and response in Chath...
# 79  Aims to be the premier institution for logisti...
#
#                                     Purpose_Embedding  \
# 0   [-0.7475531, -0.28025112, -0.5108066, -0.09811...
# 1   [-0.7059361, -0.014833092, -0.519372, -0.11807...
# 2   [-0.8444699, 0.042686164, -0.92527217, -0.0121...
# 3   [-0.9401546, -0.2008859, -0.8348193, -0.138634...
# 4   [-0.4857487, 0.15720437, -0.36733863, -0.27873...
# ..                                                ...
# 75  [-0.8119428, -0.16800997, -0.65266424, -0.2421...
# 76  [-0.806397, -0.08502055, -1.0574926, -0.420601...
# 77  [-0.82316875, 0.09686072, -0.31321028, 0.03096...
# 78  [-1.0763615, -0.4297121, -0.7915945, -0.108039...
# 79  [-0.6068448, -0.09858106, -0.37059268, -0.2740...
#
#                                           Description  \
# 0   The Advanced Manufacturing Pilot Facility (AMP...
# 1   The Advanced Technology Development Center (AT...
# 2   This NSF Artificial Intelligence (AI) Research...
# 3   The Atlanta Regional Commission (ARC) is the o...
# 4   The Brook Byers Institute for Sustainable Syst...
# ..                                                ...
# 75  The Metro Atlanta Chamber (MAC) is a 165-year-...
# 76  The Partnership for Inclusive Innovation (PIN)...
# 77  On November 15, 2019, IMT Mines Albi and the G...
# 78  The Smart Sea Level Sensors Project aims to in...
# 79  The Logistics Institute - Asia Pacific, a coll...
#
#                                 Description_Embedding
# 0   [-0.57778853, -0.2628846, -0.6567326, -0.44782...
# 1   [-0.8001564, -0.41133833, -0.7856436, 0.248099...
# 2   [-0.6534205, -0.22116624, -0.3180426, 0.109655...
# 3   [-0.5959657, 0.004410204, -0.7242155, -0.17405...
# 4   [-0.6693135, -0.14842133, -0.5588188, -0.12038...
# ..                                                ...
# 75  [-0.4659681, -0.43856305, -0.20382541, -0.3299...
# 76  [-0.5760279, -0.3649536, -0.9441599, -0.242495...
# 77  [-0.65241796, -0.13074902, -0.33428797, -0.093...
# 78  [-0.93810964, -0.528288, -0.5730109, -0.102771...
# 79  [-0.60964525, 0.10186995, -0.45152536, -0.2336...
#
# [80 rows x 5 columns]

# %% [markdown]
# # Analysis

# %%
from sklearn.decomposition import PCA

# Reduce Purpose embeddings to 2D
df['Purpose_Embedding_2D'] = PCA(n_components=2).fit_transform(list(df['Purpose_Embedding']))

# Reduce Description embeddings to 2D
df['Description_Embedding_2D'] = PCA(n_components=2).fit_transform(list(df['Description_Embedding']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/scl-WZEQTT0V-py3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Purpose_Embedding_2D'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/scl-WZEQTT0V-py3.11/lib/python3.11/site-packages/pandas/core/frame.py:4485, in DataFrame._set_item_mgr(self, key, value, refs)
#    4484 try:
# -> 4485     loc = self._info_axis.get_loc(key)
#    4486 except KeyError:
#    4487     # This item wasn't present, just insert at end
#
# File ~/.cache/pypoetry/virtualenvs/scl-WZEQTT0V-py3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#
# KeyError: 'Purpose_Embedding_2D'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 4
#       1 from sklearn.decomposition import PCA
#       3 # Reduce Purpose embeddings to 2D
# ----> 4 df['Purpose_Embedding_2D'] = PCA(n_components=2).fit_transform(list(df['Purpose_Embedding']))
#       6 # Reduce Description embeddings to 2D
#       7 df['Description_Embedding_2D'] = PCA(n_components=2).fit_transform(list(df['Description_Embedding']))
#
# File ~/.cache/pypoetry/virtualenvs/scl-WZEQTT0V-py3.11/lib/python3.11/site-packages/pandas/core/frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~/.cache/pypoetry/virtualenvs/scl-WZEQTT0V-py3.11/lib/python3.11/site-packages/pandas/core/frame.py:4538, in DataFrame._set_item(self, key, value)
#    4535             value = np.tile(value, (len(existing_piece.columns), 1)).T
#    4536             refs = None
# -> 4538 self._set_item_mgr(key, value, refs)
#
# File ~/.cache/pypoetry/virtualenvs/scl-WZEQTT0V-py3.11/lib/python3.11/site-packages/pandas/core/frame.py:4488, in DataFrame._set_item_mgr(self, key, value, refs)
#    4485     loc = self._info_axis.get_loc(key)
#    4486 except KeyError:
#    4487     # This item wasn't present, just insert at end
# -> 4488     self._mgr.insert(len(self._info_axis), key, value, refs)
#    4489 else:
#    4490     self._iset_item_mgr(loc, value, refs=refs)
#
# File ~/.cache/pypoetry/virtualenvs/scl-WZEQTT0V-py3.11/lib/python3.11/site-packages/pandas/core/internals/managers.py:1370, in BlockManager.insert(self, loc, item, value, refs)
#    1368     value = value.T
#    1369     if len(value) > 1:
# -> 1370         raise ValueError(
#    1371             f"Expected a 1D array, got an array with shape {value.T.shape}"
#    1372         )
#    1373 else:
#    1374     value = ensure_block_shape(value, ndim=self.ndim)
#
# ValueError: Expected a 1D array, got an array with shape (80, 2)

# %%
# Cosine similarity matrix for Purpose embeddings
similarity_matrix = cosine_similarity(list(df['Purpose_Embedding']))

# %%
# Set threshold for edge creation (e.g., 0.8)
threshold = 0.8
edges = np.where(similarity_matrix > threshold)
edge_list = [(i, j) for i, j in zip(edges[0], edges[1]) if i != j]

# %%
import networkx as nx
import plotly.graph_objects as go

G = nx.Graph()
for idx, entity in enumerate(df['Entity']):
    G.add_node(idx, label=entity)

# Add edges based on similarity
G.add_edges_from(edge_list)

# Use NetworkX spring layout (force-directed layout)
pos = nx.spring_layout(G)

# Extract positions for nodes
x_coords = [pos[i][0] for i in range(len(G.nodes))]
y_coords = [pos[i][1] for i in range(len(G.nodes))]

# Plot nodes in Plotly
node_trace = go.Scatter(
    x=x_coords,
    y=y_coords,
    mode='markers+text',
    marker=dict(size=10, color='skyblue'),
    text=[G.nodes[i]['label'] for i in range(len(G.nodes))],
    textposition="bottom center"
)

# Plot edges in Plotly
edge_trace = []
for edge in G.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_trace.append(
        go.Scatter(
            x=(x0, x1),
            y=(y0, y1),
            mode='lines',
            line=dict(width=0.5, color='gray')
        )
    )

# %%
fig = go.Figure(data=[node_trace] + edge_trace)
fig.update_layout(title="Network Graph of Embeddings (Without PCA)", showlegend=False)

fig.show()
# Out:
# <div>                            <div id="e0d264b9-b4c1-4e2c-b2d9-661b2ea91032" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0d264b9-b4c1-4e2c-b2d9-661b2ea91032")) {                    Plotly.newPlot(                        "e0d264b9-b4c1-4e2c-b2d9-661b2ea91032",                        [{"marker":{"color":"skyblue","size":10},"mode":"markers+text","text":["Advanced Manufacturing Pilot Facility (AMPF)","Advanced Technology Development Center (ATDC)","Artificial Intelligence Institute for Advances in Optimization (AI4OPT)","Atlanta Regional Commission (ARC)","Brook Byers Institute for Sustainable Systems (BBISS)","BS BA Operations and Supply Chain Management Concentration","BS IE Supply Chain Engineering Concentration","Center for Economic Development Research (CEDR)","Center for Predictive Analytics and Intelligent Systems (PAIS)","Center for the Development and Application of Internet of Things Technologies (CDAIT)","Center for Urban and Regional Air Mobility (CURAM)","Civil Engineering Transportation Systems Engineering","Contextual Computing Group","Enterprise Innovation Institute (EI2)","F.R.E.I.T. Forum for Research in International Trade","Factory Information Systems (FIS) Center","Georgia Artificial Intelligence in Manufacturing (Georgia AIM)","Georgia Center of Innovation Aerospace Team","Georgia Center of Innovation for Logistics","Georgia Manufacturing Extension Partnership (GaMEP)","Georgia Ports Authority","Georgia Tech Aerospace Systems Design Laboratory","Georgia Tech Center for Health and Humanitarian Systems","Georgia Tech Center for Next Generation Logistics","Georgia Tech Center for Quality Growth and Regional Development","Georgia Tech Institute for Robotics and Intelligent Machines","Georgia Tech Manufacturing Institute","Georgia Tech Panama Logistics Innovation & Research Center","Georgia Tech Physical Internet Center","Georgia Tech Professional Education (GTPE)","Georgia Tech Research Institute (GTRI)","Georgia Tech Savannah","Georgia Tech Smart Cities and Inclusive Innovation","Georgia Tech Strategic Energy Institute","Georgia Tech Supply Chain and Logistics Institute","Georgia Transportation Institute (GTI)","Institute for People and Technology (IPaT)","Laboratory for Intelligent Decision and Autonomous Robots (LIDAR)","Master of Science in Analytics","Master of Science in Analytics (Online)","Master of Science in Industrial Engineering (Online)","Master of Science in Operations Research (Online)","Master of Science in Supply Chain Engineering","MBA Operations and Supply Chain Management Concentration","Metro Atlanta Chamber of Commerce (MACOC)","MS City and Regional Planning Transportation Specialization","Net Zero Freight Systems","Operations Management Group at Scheller","Partnership for Inclusive Innovation","PhD IE Supply Chain Engineering Concentration","PhD Operations Management Concentration","Professional Master's in Applied Systems Engineering (PMASE)","Professional Master's in Manufacturing Leadership (PMML)","Ray C. Anderson Center for Sustainable Business","Renewable Bioproducts Institute (RBI)","Safety, Health, Environmental Services (SHES)","Sentient Immersive Response Networks Lab (SIReN Lab)","Smart Built Environment Eco-System (Smart Bees) Lab","Smart Sea Level Sensors Project","Socially-Aware Mobility Lab","Space Systems Optimization Group (SSOG)","Sustainable Design and Manufacturing (SDM) Laboratory","The Logistics Institute \u2013 Asia Pacific","VET\u00b2 - Military Transitions to the Workforce","RoboGeorgia","Advanced Technology Development Center (ATDC)","Artificial Intelligence Institute for Advances in Optimization (AI4OPT)","Atlanta Regional Commission (ARC)","F.R.E.I.T. Forum for Research in International Trade","Georgia Aim","Georgia Cen ...
