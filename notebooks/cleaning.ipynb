# %%
import pandas as pd

# %%
df = pd.read_csv("test_data.csv", encoding = "cp1252")

# %%
df = df.drop(["Purpose", "Description", "Information Verified "], axis=1)

# %%
df = df[(~df["Parent"].isna()) | (~df["Children"].isna())]

# %%
df
# Out:
#                                                Entity             Contact  \
# 0        Advanced Manufacturing Pilot Facility (AMPF)       Aaron Stebner
# 4   Brook Byers Institute for Sustainable Systems ...        Beril Toktay
# 7     Center for Economic Development Research (CEDR)       Leigh Hopkins
# 13              Enterprise Innovation Institute (EI2)         Donna Ennis
# 15           Factory Information Systems (FIS) Center     Andrew Dugenske
# 26               Georgia Tech Manufacturing Institute      Thomas Kurfess
# 31                              Georgia Tech Savannah           Diane Lee
# 32  Georgia Tech Smart Cities and Inclusive Innova...  Danielle Willkens
# 36         Institute for People and Technology (IPaT)        Michael Best
# 39            Master of Science in Analytics (Online)          Joel Sokol
# 40  Master of Science in Industrial Engineering (O...          Alan Erera
# 41  Master of Science in Operations Research (Online)                 NaN
# ...

# %%
df.to_csv("cleaned.csv")
